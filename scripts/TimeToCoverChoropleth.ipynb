# %%
import pandas as pd
import plotly.express as px
from pathlib import Path
import country_converter as coco
from UNregionChoroplethGenerator import create_un_region_choropleth
from UNregionChoroplethGenerator import create_un_region_choropleth_deco

cwd = Path.cwd()
cc = coco.CountryConverter()

# Input paths
results_folder =  cwd.parent / "results"
file_path_TTR_data = results_folder / "TTR_Region_MS.csv"

# Output paths
TTR_RegionsLowerBound_PATH = results_folder / "TTR_RegionsLowerBound.html"
TTR_RegionsUpperBound_PATH = results_folder / "TTR_RegionsUpperBound.html"

# %%
TTR_df = pd.read_csv(file_path_TTR_data)

# %%
TTR_RegionsLowerBound = create_un_region_choropleth(TTR_df, region_col="Region", value_col="ECW POLL in Weeks", title="Time to Minimum Coverage (weeks)", 
                                          color_scale='RdYlGn_r', projection_type= 'robinson')
TTR_RegionsUpperBound = create_un_region_choropleth(TTR_df, region_col="Region", value_col="ECW ILO in Weeks", title="Time to Minimum Coverage (weeks)", 
                                          color_scale='RdYlGn_r', projection_type= 'robinson')

# %%
TTR_RegionsUpperBound.show()

# %%
TTR_RegionsLowerBound.write_html(TTR_RegionsLowerBound_PATH)
TTR_RegionsUpperBound.write_html(TTR_RegionsLowerBou_PATH)
